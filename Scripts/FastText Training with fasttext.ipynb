# %%
from keras.preprocessing.text import Tokenizer
from gensim.models.fasttext import FastText
import numpy as np
import matplotlib.pyplot as plt
import nltk
from string import punctuation
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize
from nltk import WordPunctTokenizer

import wikipedia
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
en_stop = set(nltk.corpus.stopwords.words('english'))
import fasttext
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/kunalkhadilkar/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kunalkhadilkar/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kunalkhadilkar/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from nltk.stem import WordNetLemmatizer

stemmer = WordNetLemmatizer()

def preprocess_text(document):
        # Remove all the special characters
        document = re.sub(r'\W', ' ', str(document))

        # remove all single characters
        document = re.sub(r'\s+[a-zA-Z]\s+', ' ', document)

        # Remove single characters from the start
        document = re.sub(r'\^[a-zA-Z]\s+', ' ', document)

        # Substituting multiple spaces with single space
        document = re.sub(r'\s+', ' ', document, flags=re.I)

        # Removing prefixed 'b'
        document = re.sub(r'^b\s+', '', document)

        # Converting to Lowercase
        document = document.lower()

        # Lemmatization
        tokens = document.split()
        tokens = [stemmer.lemmatize(word) for word in tokens]
        tokens = [word for word in tokens if word not in en_stop]
        tokens = [word for word in tokens if len(word) > 3]

        preprocessed_text = ' '.join(tokens)

        return preprocessed_text

# %%
model = fasttext.train_unsupervised('../Bollywood/Corpus Files/oldfilms_corpus.txt',"cbow",dim=100,minn=2,maxn=4,epoch=10,ws=5,neg=5)

# %%
model.get_word_vector("poor")
# Out:
# array([-0.20204009,  1.4386978 , -1.9977598 ,  0.98822886, -0.500799  ,
#        -0.10089114, -0.6208778 , -0.7784032 , -0.16671225,  3.3676202 ,
#         1.1655308 ,  1.5486842 ,  0.5969884 , -0.3554499 ,  1.5619173 ,
#        -0.7438434 , -1.4361495 ,  0.82883507, -0.11856832, -0.5192899 ,
#        -0.77916044, -1.9974706 ,  2.1924844 , -1.4068047 ,  0.6935916 ,
#        -1.3591009 , -2.126033  , -1.1739305 ,  0.5869837 ,  1.8625911 ,
#         0.33364946,  2.135224  ,  1.0779238 , -1.2014587 ,  1.7863123 ,
#         0.9643411 , -2.585858  , -0.38596818, -0.13989742, -0.59178257,
#         1.488526  , -3.132451  , -0.5825881 ,  3.317188  ,  0.41597226,
#         1.661552  , -0.859436  , -0.09808455,  0.22264262, -0.8339267 ,
#         0.10456317,  1.9922185 ,  0.9655168 , -0.078836  ,  0.38072792,
#         0.4752923 ,  1.3210411 ,  0.43555444,  0.78930086, -2.1731074 ,
#         1.8768315 , -2.1499233 , -0.24568388, -1.964112  ,  1.5121272 ,
# ...

# %%
 temp_list = model.get_nearest_neighbors('man',50)

# %%
sample_list = []
for i in temp_list:
    sample_list.append(i[1])

# %%
print(sample_list)
# Out:
# ['Laxman', 'Roman', 'magician', 'woman', 'Woman', 'Jumman', 'human', 'Suman', 'man"', 'Hanuman', 'postman', 'many', 'Sumanth', 'mansion', 'boatman', 'man!', 'manage', 'humanity', 'man.', 'manner', "man's", 'mama', 'malign', 'woman!', 'gentleman', 'manager', 'Ioan', 'woman.', 'man?', 'man,', 'woman,', 'humans', 'Romans', "woman's", 'mantle!', 'woman?', 'Suman.', 'many.', 'magician.', 'human.', 'Roman.', 'romantic', 'an', 'Chaman', 'human,', 'Jeevan', 'manage.', 'mean', 'manager.', 'fan']

# %%
model.get_analogies("ugly", "dark","fair")
# Out:
# [(0.6070298552513123, 'fully'),
#  (0.5523486137390137, 'fairy'),
#  (0.5446798801422119, 'fly'),
#  (0.524328887462616, 'softly'),
#  (0.5204453468322754, 'safely'),
#  (0.5114834308624268, 'extremely'),
#  (0.5110819935798645, 'funny'),
#  (0.5037431716918945, 'Prabir'),
#  (0.4895140528678894, 'forcibly'),
#  (0.4852500259876251, 'ly')]

# %%
model.words
# Out:
# ['</s>',
#  'I',
#  'the',
#  'you',
#  'to',
#  'a',
#  'is',
#  'of',
#  'my',
#  'in',
#  'and',
#  'your',
#  'have',
#  'will',
#  'You',
#  'are',
#  'e',
#  'for',
#  'me',
#  'this',
#  'that',
#  'be',
#  'o',
#  'What',
#  'not',
#  'it',
#  'with',
#  'The',
#  'has',
#  "don't",
#  'But',
#  "I'll",
#  'do',
#  "I'm",
#  'you.',
#  'i',
#  'at',
#  'was',
#  'r',
#  'me.',
#  'come',
#  'h',
#  'can',
#  'And',
#  'he',
#  's',
#  'on',
#  'n',
#  'go',
#  'from',
#  't',
#  'Why',
#  'what',
#  'get',
#  'He',
#  'her',
#  "Don't",
#  'one',
#  'My',
#  'like',
#  'am',
#  'know',
#  'his',
#  'want',
#  'him',
#  'all',
#  'so',
#  'if',
#  'take',
#  'who',
#  'This',
#  'd',
#  'as',
#  'we',
#  'u',
#  'How',
#  'did',
#  'love',
#  'm',
#  'Come',
#  'but',
#  'see',
#  'she',
#  'very',
#  'no',
#  'about',
#  'it.',
#  "won't",
#  "I've",
#  'had',
#  'you?',
#  'If',
#  'heart',
#  'Where',
#  'tell',
#  'or',
#  'We',
#  'here.',
#  'only',
#  'give',
#  'c',
# ...
